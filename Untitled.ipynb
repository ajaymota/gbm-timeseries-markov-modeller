# %%
import pandas as pd
import numpy as np
import quandl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
prices = quandl.get("BSE/BOM532540", 
                authtoken="", 
                start_date = '1991-01-01', end_date = '2022-10-11'
                )

# %%
prices = prices[['WAP']]
prices.rename(columns = {'WAP':'Price'}, inplace = True)

# %%
prices
# Out:
#                   Price
# Date
# 2004-08-25  1004.163872
# 2004-08-26   985.243466
# 2004-08-27   969.424008
# 2004-08-30   982.607932
# 2004-08-31   982.258276
# ...                 ...
# 2022-10-04  3079.310000
# 2022-10-06  3107.810000
# 2022-10-07  3075.370000
# 2022-10-10  3097.620000
# 2022-10-11  3113.850000
#
# [4499 rows x 1 columns]

# %%
sns.lineplot(prices)
# Out:
# <AxesSubplot:xlabel='Date'>
